# %%
from trading.model_tools import ta_transform
import trading.model_tools as mt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = mt.fetch_data(
    symbols=["SOL-USDT", "BTC-USDT"],
    days=730,
    interval="1h",
    age_days=0,
    data_source="binance",
    cache_expiry_hours=-1,
    verbose=True,
)

features = ta_transform(data, add_ticker="BTC-USDT")
# Out:
# FETCHING DATASET(S) SOL-USDT, BTC-USDT; 730d of 1h
# DOWNLOADING DATA
# BINANCE PROGRESS: 100%|██████████| 1052/1052 [00:10<00:00, 105.12it/s]
# C:\Users\fluidize\Documents\qtech\trading\model_tools.py:296: RuntimeWarning: coroutine '_fetch_binance.<locals>.download_all_chunks' was never awaited
#   with concurrent.futures.ThreadPoolExecutor() as executor:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# BINANCE PROGRESS: 100%|██████████| 1052/1052 [00:09<00:00, 107.39it/s]
# C:\Users\fluidize\Documents\qtech\trading\model_tools.py:296: RuntimeWarning: coroutine '_fetch_binance.<locals>.download_all_chunks' was never awaited
#   with concurrent.futures.ThreadPoolExecutor() as executor:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Data cached to C:\Users\fluidize\AppData\Roaming\market_data\SOL-USDT_BTC-USDT_730_1h_0_binance.csv (3.04 MB 17534
# bars)

# %%
corr_matrix = features.corr()
plt.figure(figsize=(16,12))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
plt.plot(features["vol_ratio"], features["add_vol_ratio"], 'o')
